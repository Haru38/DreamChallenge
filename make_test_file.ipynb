# %%
# dilution_leaderboard.txt
# leaderboard_set.txt
# CID_leaderboard.txt

# %%
lb_cid = []
with open('data/CID_leaderboard.txt') as file:
    for f in file:
        line = f.split('\t')
        value = int(line[0].split('\n')[0])
        lb_cid.append(value)

# %%
lb_set = []
with open('data/leaderboard_set.txt') as file:
    for f in file:
        line = f.split('\t')
        lb_set.append(line)

# %%
lb_set
# Out:
# [['#oID', 'individual', 'descriptor', 'value\n'],
#  ['243', '1', 'INTENSITY/STRENGTH', '22\n'],
#  ['454', '1', 'INTENSITY/STRENGTH', '33\n'],
#  ['679', '1', 'INTENSITY/STRENGTH', '2\n'],
#  ['1030', '1', 'INTENSITY/STRENGTH', '0\n'],
#  ['1060', '1', 'INTENSITY/STRENGTH', '5\n'],
#  ['2682', '1', 'INTENSITY/STRENGTH', '60\n'],
#  ['6137', '1', 'INTENSITY/STRENGTH', '92\n'],
#  ['6386', '1', 'INTENSITY/STRENGTH', '59\n'],
#  ['6826', '1', 'INTENSITY/STRENGTH', '60\n'],
#  ['6989', '1', 'INTENSITY/STRENGTH', '71\n'],
#  ['7047', '1', 'INTENSITY/STRENGTH', '22\n'],
#  ['7409', '1', 'INTENSITY/STRENGTH', '0\n'],
#  ['7601', '1', 'INTENSITY/STRENGTH', '0\n'],
#  ['7632', '1', 'INTENSITY/STRENGTH', '0\n'],
#  ['7792', '1', 'INTENSITY/STRENGTH', '0\n'],
#  ['7820', '1', 'INTENSITY/STRENGTH', '79\n'],
#  ['7826', '1', 'INTENSITY/STRENGTH', '15\n'],
#  ['8038', '1', 'INTENSITY/STRENGTH', '0\n'],
#  ['8048', '1', 'INTENSITY/STRENGTH', '64\n'],
#  ['8051', '1', 'INTENSITY/STRENGTH', '0\n'],
# ...
